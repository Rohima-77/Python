# %%
# Polymorphism means one method name but different behavior in different classes
# method overriding
class Grandfather:
    def greet(self):
      print("Grandfather says")

class Father(Grandfather):
    def greet(self):
      print("Father says")

class Children(Father):
    def greet(self):
      print("Children says")

g1 = Grandfather()
f1 = Father()
c1 = Children()

g1.greet()
f1.greet()
c1.greet()
# Out:
# Grandfather says
# Father says
# Children says

# %%
#polymorphism
#method overloading
# same name er function but parametter & return type different tahke
class Shape:
    def area(self,a,b=12):
      return a*b

s1 = Shape()
print(s1.area(14))
print(s1.area(14,12))
# Out:
# 168
# 168
